# %%
# set


set={12,33.5,44,2,'abc'}
print(set)
# Out:
# {33.5, 2, 'abc', 12, 44}

# %%
set={12,2,33.5,2,44,2,'abc'}
print(set)
# Out:
# {33.5, 2, 'abc', 12, 44}

# %%
set1= {}
type(set1)
# Out:
# dict

# %%
set1={11,22,33}
set1.add(20)
print(set1)
# Out:
# {33, 11, 20, 22}

# %%
set1={11,22,33}
set1.update({20,30})
print(set1)
# Out:
# {33, 20, 22, 11, 30}

# %%
set1={11,22,33}
set1.remove(22)
print(set1)
# Out:
# {33, 11}

# %%
set1={11,22,33}
set1.discard(22)
print(set1)
# Out:
# {33, 11}

# %%
set1={11,22,33}
set1.pop()
print(set1)
# Out:
# {11, 22}

# %%
set1={11,22,33}
print(len(set1))
# Out:
# 3

# %%
set1={11,22,33}
set2={'c','b','a'}
set1 | set2
# Out:
# {11, 22, 33, 'a', 'b', 'c'}

# %%
set1={11,22,33}
set2={'c','b','a',22}
set1 & set2
# Out:
# {22}

# %%
set1={11,22,33}
set2={'c','b','a',22}
set1 - set2
# Out:
# {11, 33}

# %%
set1={11,22,33}
set2={'c','b','a',22}
set2 - set1
# Out:
# {'a', 'b', 'c'}

# %%
set1={11,22,33}
set2={'c','b','a',22}
set2 ^ set1
# Out:
# {11, 33, 'a', 'b', 'c'}

# %%
# tuple


tpl=(1,2,-1,22,-3)
print(tpl)
# Out:
# (1, 2, -1, 22, -3)

# %%
tpl=('a',22,-1,22,39.6)
print(tpl)
# Out:
# ('a', 22, -1, 22, 39.6)

# %%
tpl=(11,)
type(tpl)
# Out:
# tuple

# %%
tpl=('a',22,-1,22,39.6)
print(tpl[0],tpl[4])
# Out:
# a 39.6

# %%
tpl=('a',22,-1,22,39.6)
print(tpl[2])
# Out:
# -1

# %%
tpl=('a',22,-1,22,39.6)
print(tpl[0:3])
# Out:
# ('a', 22, -1)

# %%
tpl=('a',2,-1,22,39.6)
print(tpl[:2:-1])
# Out:
# (39.6, 22)

# %%
tpl=('a',2,-1,22,39.6)
print(tpl[::-1])
# Out:
# (39.6, 22, -1, 2, 'a')

# %%
tpl=('a',2,-1,2,2,39.6)
tpl.count(2)
# Out:
# 3

# %%
tpl=('a',2,-1,2,2,39.6)
tpl.index(-1)
# Out:
# 2

# %%
tpl=('a',2,-1,2,2,39.6)
print(type(tpl))
lst=list(tpl)
print(type(lst))
lst.insert(2,39)
print(lst)
tpl=tuple(lst)
print(tpl)
# Out:
# <class 'tuple'>
# <class 'list'>
# ['a', 2, 39, -1, 2, 2, 39.6]
# ('a', 2, 39, -1, 2, 2, 39.6)

# %%
# basic python

# variables(basic)
name ='simran'
print(name)
age=19
print(age)
# Out:
# simran
# 19

# %%
price=19.50
print(price)
# Out:
# 19.5

# %%
a=10
b=20
c=30
sum=a+b+c
print(sum)
# Out:
# 60

# %%
is_student=True
print(is_student)
# Out:
# True

# %%
# user input(basic)
name=input("enter your name")
print("hello ",name)
# Out:
# enter your name simran
# hello  simran

# %%
age=input("enter your age")
print("your age is ",age)
# Out:
# enter your age 19
# your age is  19

# %%
city=input("enter your city's name")
print("you live in ",city)
# Out:
# enter your city's name kharar
# you live in  kharar

# %%
fav_num=input("enter your fav number")
print("fav number is ",fav_num)
# Out:
# enter your fav number 8
# fav number is  8

# %%
# type casting
n=int(input("enter your number"))
print("square ",n**2)
# Out:
# enter your number 5
# square  25

# %%
a=int(input("enter your number"))
b=int(input("enter your number"))
print(a+b)
# Out:
# enter your number 2
# enter your number 3
# 5

# %%
n=input("enter your number")
print(type(n))
n=int(n)
print(type(n))
# Out:
# enter your number 55
# <class 'str'>
# <class 'int'>

# %%
n=float(input("enter your number"))
print(type(n))
n=int(n)
print(n)
print(type(n))
# Out:
# enter your number 55.3
# <class 'float'>
# 55
# <class 'int'>

# %%
# mixed questions
name=input("enter your name")
age=input("enter your age")
print("My name is",name," and i am ",age)
# Out:
# enter your name simran
# enter your age 19
# My name is simran  and i am  19

# %%
length=int(input("length="))
breadth=int(input("breadth="))
area=length*breadth
print(area)
# Out:
# length= 20
# breadth= 10
# 200

# %%
a=int(input("no.1="))
b=int(input("no.2="))
c=int(input("no.3="))
average=(a+b+c)/3
print(average)
# Out:
# no.1= 2
# no.2= 3
# no.3= 4
# 3.0

# %%
# bonus mini project

name=input("enter your name")
roll_no=int(input("enter your roll no."))
marks=int(input("enter your marks"))
print("roll no.",roll_no,name,"scored",marks,"in their exam")
# Out:
# enter your name simran
# enter your roll no. 6
# enter your marks 98
# roll no. 6 simran scored 98 in their exam

# %%
# list


fruits = ["apple", "banana" , "kiwi", "grapes", "pear"]
print(fruits)
# Out:
# ['apple', 'banana', 'kiwi', 'grapes', 'pear']

# %%
fruits = ["apple", "banana" , "kiwi", "grapes", "pear"]

print(fruits[0])
print(fruits[-1])
# Out:
# apple
# pear

# %%
fruits = ["apple", "banana" , "kiwi", "grapes", "pear"]

print(len(fruits))
# Out:
# 5

# %%
list = []
print(list)
list.append(10)
list.append(20)
list.append(30)
print(list)
# Out:
# []
# [10, 20, 30]

# %%
list=[10,20,30]
list.append(50)
print(list)
# Out:
# [10, 20, 30, 50]

# %%
list=[10,20,30]
list.insert(2,50)
print(list)
# Out:
# [10, 20, 50, 30]

# %%
list=[10,20,30]
list.insert(0,'Python')
print(list)
# Out:
# ['Python', 10, 20, 30]

# %%
list1=[10,20,30]
list2=['a' , 'b', 'c']
list1.extend(list2)
print(list1)
# Out:
# [10, 20, 30, 'a', 'b', 'c']

# %%
list=[10,20,30]
list.remove(20)
print(list)
# Out:
# [10, 30]

# %%
list=[10,20,30]
list.pop()
print(list)
# Out:
# [10, 20]

# %%
list=[10,20,30]
list.pop(1)
print(list)
# Out:
# [10, 30]

# %%
list=[30,22,85,11,43,20]
list.sort()
print(list)
# Out:
# [11, 20, 22, 30, 43, 85]

# %%
list=[30,22,85,11,43,20]
list.sort(reverse = True )
print(list)
# Out:
# [85, 43, 30, 22, 20, 11]

# %%
list=[30,22,85,11,43,20]
print(sorted(list))
print(list)
# Out:
# [11, 20, 22, 30, 43, 85]
# [30, 22, 85, 11, 43, 20]

# %%
list=[30,22,85,11,43,20]
list.reverse()
print(list)
# Out:
# [20, 43, 11, 85, 22, 30]

# %%
list=[30,22,85,11,43,20]
list.index(85)
# Out:
# 2

# %%
list=[30,22,85,22,11,43,22,22,20]
list.count(22)
# Out:
# 4

# %%
# string slicing(basic)


str="Programming"
print(str[:4])
# Out:
# Prog

# %%
str="Python"
print(str[3:])
# Out:
# hon

# %%
str="Developer"
print(str[2:7])
# Out:
# velop

# %%
text='Computer'
print(text[1:5])
# Out:
# ompu

# %%
str="HelloWorld"
print(str[::-1])
# Out:
# dlroWolleH

# %%
# advanced slicing

str="Artificial"
print(str[::2])
# Out:
# Atfca

# %%
str="Python"
print(str[::-1])
# Out:
# nohtyP

# %%
word="Programming"
print(word[::3])
# Out:
# Pgmn

# %%
# f-strings

name="Simran"
age=19
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Simran and I am 19 years old

# %%
city=input("enter name of city: ")
country=input("enter name of country: ")
print(f"I am from {city} in {country}")
# Out:
# enter name of city:  kharar
# enter name of country:  india
# I am from kharar in india

# %%
import math
pi=math.pi
print(f"The value of pi is {pi}")
# Out:
# The value of pi is 3.141592653589793

# %%
# format()

name="Simran"
print("Hello {},welcome to python".format(name))
# Out:
# Hello Simran,welcome to python

# %%
subject="english"
marks=50
print("the marks scored in {} are {}".format(subject,marks))
# Out:
# the marks scored in english are 50

# %%
# mixed (slicing+formatting)


str=input("enter a string")
print(str)
print(str[:len(str)//2])
# Out:
# enter a string python
# python
# pyt

# %%
str=input("enter a string")
print(f"the string is {str}")

str2=str[::-1]
print(f"the reversed string is {str2}")
# Out:
# enter a string abcd
# the string is abcd
# the reversed string is dcba

# %%
str="PythonProgramming"
str2=str[:6]
print(f"the string is {str2}")
# Out:
# the string is Python

# %%
# bonus mini task

name=input("enter your full name")
firstName=name[:name.index(" ")]
print(f"first name is {firstName}")
# Out:
# enter your full name simran kaur
# first name is simran

# %%
# string & indexing


name="simranjeet kaur"
print(name)
# Out:
# simranjeet kaur

# %%
str="Python"
print(str[0])
# Out:
# P

# %%
str="Programming"
print(str[-1])
# Out:
# g

# %%
text='Developer'
print(text[3])
# Out:
# e

# %%
word='Python'
print(word[-2])
# Out:
# o

# %%
# length & case

str='Artificial Intelligence'
len(str)
# Out:
# 23

# %%
str='python programming'
str.upper()
# Out:
# 'PYTHON PROGRAMMING'

# %%
str='PYTHON PROGRAMMING'
str.lower()
# Out:
# 'python programming'

# %%
str='python programming'
str.title()
# Out:
# 'Python Programming'

# %%
# searching & counting

str='banana'
str.count('a')
# Out:
# 3

# %%
str='I love data science'
str.find('data')     #can use index() also
# Out:
# 7

# %%
str='I love data science'
str.find('date')   #find() returns -1 if value not found
# str.index('data')   #returns error
# Out:
# -1

# %%
# startswith & endswith

str='python.py'
str.endswith('.py')
# Out:
# True

# %%
str='https://google.com'
str.startswith('https')
# Out:
# True

# %%
str=input('enter your name:')
str.startswith('Mr')
# Out:
# enter your name: Mr yuvraj
# True

# %%
# validation method

str='Python123'
str.isalnum()
# Out:
# True

# %%
str=' '
str.isspace()
# Out:
# True

# %%
str='hello'
str.islower()
# Out:
# True

# %%
str='HELLO'
str.isupper()
# Out:
# True

# %%
str='Python Programming'
str.istitle()
# Out:
# True

# %%
# strip methods

str='      Python'
str.lstrip()
# Out:
# 'Python'

# %%
str='Python    '
str.rstrip()
# Out:
# 'Python'

# %%
str='     Python    '
str.strip()
# Out:
# 'Python'

# %%
# replace, join & split


str='I love java'
str.replace('java','python')
# Out:
# 'I love python'

# %%
lst=['Python','is','awesome']
lst2=' '
lst2.join(lst)
# Out:
# 'Python is awesome'

# %%
str='apple,banana,orange'
str2=','
str.split(str2)
# Out:
# ['apple', 'banana', 'orange']

# %%
# partition


str='user@email.com'
str.partition('@')          #always in 3 parts partitioned
# str.partition(' ')
# Out:
# ('user', '@', 'email.com')

# %%
text='Python-is-fun'
print(text.partition('-'))
# Out:
# ('Python', '-', 'is-fun')

# %%
# user input based


str=input('enter a string')
print(str.upper())
str.isalpha()
# Out:
# enter a string simran
# SIMRAN
# True

# %%
str=input('enter your email_id')
print(str[0].isalpha())
print(str.endswith('.com'))
# Out:
# enter your email_id simran@gmail.com
# True
# True

# %%
# bonus mini task

username = input("Enter username: ")
username=username.strip()
print(username)
print(username.isalnum())
print(username[0].isalpha())
# Out:
# Enter username:     simran123
# simran123
# True
# True

# %%
# simple if

num=2
if num>0:
    print('positive')
# Out:
# positive

# %%
num=55
if num>50:
    print('greater')
# Out:
# greater

# %%
num=2
if num%2==0:
    print('even')
# Out:
# even

# %%
age=19
if age>=18:
    print('adult')
# Out:
# adult

# %%
str=input('enter python')
if str=='Python':
    print('Hello')
# Out:
# enter python Python
# Hello

# %%
# if-else


num=int(input('enter a num'))
if num%2==0:
    print('even')
else:
    print ('odd')
# Out:
# enter a num 3
# odd

# %%
age=int(input('enter your age'))
if age>=18:
    print('eligible')
else:
    print('not eligible')
# Out:
# enter your age 18
# eligible

# %%
num=int(input('enter your num'))
if num>=0:
    print('positive')
else:
    print('negative')
# Out:
# enter your num 5
# positive

# %%
marks=int(input('enter your marks'))
if marks>=40:
    print('pass')
else:
    print('fail')
# Out:
# enter your marks 45
# pass

# %%
num=int(input('enter a num'))
if num%5==0:
    print('divisible')
else:
    print ('not divisible')
# Out:
# enter a num 77
# not divisible

# %%
# if-elif-else


marks=int(input('enter your marks'))
if marks>=90:
    print('A')
elif marks>=75:
    print('B')
elif marks>=60:
    print('C')
else:
    print('FAIL')
# Out:
# enter your marks 100
# A

# %%
day=int(input('ENTER A NUMBER FROM(1-7):'))
if day==1:
    print('monday')
elif day==2:
    print('Tuesday')
elif day==3:
    print('Wednesday')
elif day==4:
    print('Thursday')
elif day==5:
    print('Friday')
elif day==6:
    print('Saturday')
else:
    print('Sunday')
# Out:
# ENTER A NUMBER FROM(1-7): 5
# Friday

# %%
temp=int(input('enter the temperature'))
if temp>30:
    print('Hot')
elif 20<temp>=30:
    print('Normal')
elif temp<=20:
    print('cold')
# Out:
# enter the temperature 20
# cold

# %%
color=input('enter the color')
color=color.lower()
if color=='red':
    print('stop')
elif color=='yellow':
    print('wait')
elif color=='green':
    print('go')
else:
    print('invalid input')
# Out:
# enter the color RED
# stop

# %%
# largest of 3 using list
lst=[23,42,80]
if lst[0]>lst[1] and lst[0]>lst[2]:
    print(lst[0],'is greater')
elif lst[1]>lst[0] and lst[1]>lst[2]:
    print(lst[1],'is greater')
else:
    print(lst[2],'is greater')
# Out:
# 80 is greater

# %%
# nested if


age=int(input('enter your age'))

if age>=18:
    print('age passed')
    id_card=input('do u have an id card(True/False)')
    if id_card=='True':
        print('allowed')
    else:
        print('not allowed')
else:
    print('age is less')
# Out:
# enter your age 19
# age passed
# do u have an id card(True/False) True
# allowed

# %%
username='simran'
password='simran123'
username1=input('enter username')
if username1.lower()==username:
    print('correct username')
    password1=input('enter password')
    if password1==password:
        print('correct password \n logged in')
    else:
        print('incorrect password')
else:
    print('incorrect username')
# Out:
# enter username simran
# correct username
# enter password simran123
# correct password
#  logged in

# %%
num=int(input('enter your number'))
if num>0:
    print('positive')
    if num%2==0:
        print('even')
    else:
        print('odd')
elif num==0:
    print('zero is even')
else:
    print('negative')
# Out:
# enter your number -1
# negative

# %%
# logical operator


num=int(input('enter a num'))
if num>10 and num<50:
    print('number between 10 and 50')
# Out:
# enter a num 45
# number between 10 and 50

# %%
age=int(input('enter your age'))
degree=input('do u have a degree?(yes or no)')
degree=degree.lower()
if age>=21 and degree=='yes':
    print('eligible')
else:
    print('not eligible')
# Out:
# enter your age 21
# do u have a degree?(yes or no) yes
# eligible

# %%
ticket=input('do u have a ticket?(yes or no)')
ticket=ticket.lower()
vip_pass=input('do u have a vip pass?(yes or no)')
vip_pass=vip_pass.lower()
if vip_pass=='yes' or ticket=='yes':
    print('allow entry')
else:
    print('not allowed')
# Out:
# do u have a ticket?(yes or no) yes
# do u have a vip pass?(yes or no) no
# allow entry

# %%
blocked = input("Are you blocked? (yes/no): ")
if blocked.lower() != "yes":
    print("Access allowed")
else:
    print("Access denied")
# Out:
# Are you blocked? (yes/no):  yes
# Access denied

# %%
# shorthand/ternary


num=int(input('enter a num'))
if num>=0: print('positive')
# Out:
# enter a num 2
# positive

# %%
num=int(input('enter a num'))
print('even'if num%2==0 else 'odd')
# Out:
# enter a num 4
# even

# %%
marks=int(input('enter marks'))
print('pass'if marks>30 else 'fail')
# Out:
# enter marks 45
# pass

# %%
# user input based


a=int(input('enter first num'))
b=int(input('enter sec num'))
print('a is greater'if a>b else 'b is greater')
# Out:
# enter first num 23
# enter sec num 32
# b is greater

# %%
marks=int(input('enter marks'))
if marks>90:
    print('A')
if marks>70:
    print('B')
if marks>50:
    print('C')
else:
    print('F')
# Out:
# enter marks 57
# C

# %%
num=int(input('enter a num'))
if num%3==0 and num%5==0:
    print('divisible by 3 and 5')
elif num%5==0:
    print('divisible by 5')
elif num%3==0:
    print('divisible by 5')
else:
    print('not divisible by both')
# Out:
# enter a num 15
# divisible by 3 and 5

# %%
age=int(input('enter age'))
if age>=50:
    print('SENIOR')
elif age>=18:
    print('ADULT')
elif age>=13:
    print('TEEN')
elif age>0:
    print('KID')
else:
    print('INVALID AGE')
# Out:
# enter age 59
# SENIOR

# %%
# challenge questions
